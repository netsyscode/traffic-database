# %%
import numpy as np

# %%
with open("quarTurple_1w.log") as file:
    lines = file.readlines()

data = []

for line in lines[2:-1]:
    data.append(int(line))

data
# Out:
# [15570,
#  2189,
#  1486,
#  1424,
#  2270,
#  1314,
#  1322,
#  1506,
#  1282,
#  1236,
#  1501,
#  1933,
#  1381,
#  1264,
#  1107,
#  1802,
#  975,
#  1659,
#  1602,
#  1489,
#  1590,
#  1350,
#  1329,
#  1316,
#  498,
#  1769,
#  1807,
#  1596,
#  1919,
#  1561,
#  1160,
#  1913,
#  1146,
#  1398,
#  1240,
#  1202,
#  1149,
#  1169,
#  1136,
#  1516,
#  1037,
#  1311,
#  1689,
#  1430,
#  1629,
#  1515,
#  791,
#  1619,
#  1605,
#  1492,
#  782,
#  684,
#  1499,
#  700,
#  645,
#  1267,
#  1622,
#  984,
#  1036,
#  1104,
#  1237,
#  815,
#  775,
#  1211,
#  1980,
#  864,
#  803,
#  1198,
#  857,
#  828,
#  1266,
#  1419,
#  1483,
#  1450,
#  809,
#  952,
#  749,
#  1130,
#  1117,
#  1333,
#  1719,
#  1525,
#  750,
#  1566,
#  1330,
#  1322,
#  899,
#  1717,
#  1027,
#  755,
#  1007,
#  747,
#  1096,
#  832,
#  1113,
#  727,
#  979,
#  1152,
#  743,
#  785,
#  888,
#  2005,
#  1201,
#  401,
#  1070,
#  628,
#  380,
#  979,
#  751,
#  789,
#  793,
#  891,
#  1309,
#  1626,
# ...

# %%
quatile = {}

for i in range(0,11):
    quatile[i*10] = np.percentile(data,i*10)

quatile
# Out:
# {0: 232.0,
#  10: 296.0,
#  20: 383.0,
#  30: 584.0,
#  40: 658.0,
#  50: 711.0,
#  60: 763.0,
#  70: 817.0,
#  80: 890.0,
#  90: 1007.0,
#  100: 15570.0}

# %%
for k, v in quatile.items():
    print(k,v/1000)
# Out:
# 0 0.232
# 10 0.296
# 20 0.383
# 30 0.584
# 40 0.658
# 50 0.711
# 60 0.763
# 70 0.817
# 80 0.89
# 90 1.007
# 100 15.57
